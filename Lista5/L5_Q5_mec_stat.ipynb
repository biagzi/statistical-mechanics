# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
m1 = [11.361, 13.787,14.307,15.651,16.938,18.209,19.212,19.976]
h1 = [-16.48730,348.17090,792.73490,2614.91570,5349.33660,9354.38630,13454.96840,16989.94320]
t1 = 0.00871852
t1_plot = 621.93

m2 = [10.452,12.646,14.322,15.78,17.271,18.348,19.141]
h2 = [19.2364,858.0122,2667.1454,5394.846,9391.2497,13488.9236,17022.7587]
t2 = 0.00572202741
t2_plot = 623.81

m3 = [8.114,10.626,12.752,14.519,16.198,17.395,18.293]
h3 = [111.1198,937.3982,2728.8464,5444.4033,9433.4186,13526.3765,17056.0851]
t3 = 0.00274147274
t3_plot = 625.68

m4 = [4.235,7.567,10.312,12.775,14.385,15.504]
h4 = [1188.5645,2932.6169,5609.7384,9567.9425,13644.6695,17165.6928]
t4 = 0.00626394644
t4_plot = 631.33

# %%
beta = -0.378
gama = -1.34
delta = beta + gama

# %%
plot_m1 = [np.log(i*(t1**(beta))) for i in m1]; plot_h1 = [np.log(i*(t1**(delta))) for i in h1]
plot_m2 = [np.log(i*(t2**(beta))) for i in m2]; plot_h2 = [np.log(i*(t2**(delta))) for i in h2]
plot_m3 = [np.log(i*(t3**(beta))) for i in m3]; plot_h3 = [np.log(i*(t3**(delta))) for i in h3]
plot_m4 = [np.log(i*(t4**(beta))) for i in m4]; plot_h4 = [np.log(i*(t4**(delta))) for i in h4]
# Out:
# /home/renata/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(plot_h1,plot_m1,'.-',label='T= %1.2f K'%t1_plot) 
plt.plot(plot_h2,plot_m2,'.-',label='T= %1.2f K'%t2_plot)
plt.plot(plot_h3,plot_m3,'.-',label='T= %1.2f K'%t3_plot)  
plt.plot(plot_h4,plot_m4,'.-',label='T= %1.2f K'%t4_plot)  


plt.xlabel(r'$\log{\left(H.|t|^{-\Delta}\right)}$')
plt.ylabel(r'$\log{\left(m.|t|^{-\beta}\right)}$')
plt.legend()
